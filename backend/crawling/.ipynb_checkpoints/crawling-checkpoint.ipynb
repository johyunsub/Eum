# %%
pip install BeautifulSoup4==4.8.2
# Out:
# Requirement already satisfied: BeautifulSoup4==4.8.2 in c:\users\sskim\anaconda3\lib\site-packages (4.8.2)
# Requirement already satisfied: soupsieve>=1.2 in c:\users\sskim\anaconda3\lib\site-packages (from BeautifulSoup4==4.8.2) (1.9.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup as bs
import urllib.request
import requests
import os
import pymysql
import uuid
from urllib.request import Request, urlopen
from urllib.parse import urlencode, quote_plus
import re
from datetime import datetime

# %%
juso_db = pymysql.connect(
    user='ssafy', 
    passwd='ssafy', 
    host='127.0.0.1', 
    db='ieum', 
    charset='utf8'
)

# %%
def getanimalnum(pageNum):
    ##다운 받을 주소
    baseUrl = 'https://www.zooseyo.or.kr/Yu_board/freesale_ty_1.html?animal=%EA%B0%95%EC%95%84%EC%A7%80&area=&ty=1&page='   
    url = baseUrl+str(pageNum)  
    req=requests.get(url)
    print(req)
    html = req.text
    soup = bs(html, "html.parser")
    info=soup.select('a[href]')
    checkpoint=False
    ct=0;
    animalnum=[]
    for i in info:
        tags=i.get('href')
        if("sell_up.html?gort=g"==tags):
            ct+=1
        num=tags.split("&")[0].split("?")
        if(ct>1 and num[0]=="view.html"):
            animalnum.append(num[1].split("=")[1])
            
    return animalnum

# %%
def getinfo(animalNum):
    preUrl='https://www.zooseyo.or.kr/Yu_board/view.html?no='
    postUrl='&page=1&animal=&area='
    url=preUrl+animalNum+postUrl
    dogsinfo=[]
    
    req=requests.get(url)
    html = req.text
    soup = bs(html, "html.parser")

    #개번호 등록
    dogsinfo.append(animalNum)    
    
    #url 등록
    dogsinfo.append(url)

    
    ##img 경로등록
    imginfo=soup.select('img[src]')
    imglist=[]
    for i in imginfo:
        tags=i.get('src')
        if('/dog_sale/' in tags):
#             print(tags)
            imglist.append('https://www.zooseyo.or.kr'+tags)
    dogsinfo.append(imglist)

    ##개정보 등록
    infos=soup.get_text().split()
    
   ##날짜 인덱스 찾기
    #print(infos)
    for i in range(len(infos)):
        try:
            if"무료분양" in infos[i]:
                dogsinfo.append(infos[i].split("(")[1])
                break
        except:
            dogsinfo.append("")
    
    
    
#     idx=0
#     for i in range(300,500):
#         print(i,infos[i] )
        
    
    for idx in [356,364,366,368]:
        dogsinfo.append(infos[idx])
    

    
    
    return dogsinfo

# %%
def saveimg(directory,url):    
    urls=url.split("/")
    extension=urls[len(urls)-1].split(".")[1]
    date=datetime.today()
    month=int(datetime.today().month/10)*10+int(datetime.today().month%10)
    day=int(datetime.today().day/10)*10+int(datetime.today().day%10)
    path1=str(datetime.today().year)+str(month)+ str(day)
    
    n=1
    imguuid=uuid.uuid1();
    save_path= directory+"/"+path1
    save_root = directory+"/"+path1
    if not os.path.exists(save_root):os.makedirs(save_root)
    try:
        with urlopen(url) as f:
            with open(os.path.join(save_path, str(imguuid)+"."+extension),'wb') as h: # w - write b - binary
                img = f.read()
                h.write(img)
        print(f"directory :  {save_path}  파일명 : {imguuid} 원본 파일명 : {urls[len(urls)-1]}")
    except:
        print("error")
    return [save_path,str(imguuid)+"."+extension,"",extension,urls[len(urls)-1]]

# %%
def saveAndInsert(dogInfos):
    dognum=info[0]
    detailurl=info[1]
    imgurls=info[2]
    date=info[3].split(".")
    date=date[0]+"-"+date[1]+"-"+date[2]
    breed=info[4]
    location=info[5]
    sex=info[6]
    phoneNumRegex = re.compile(r'\d{3}-\d{4}-\d{4}')
    phone=phoneNumRegex.findall(info[7])
    if phone==[]:
        phone=""
    else:
        phone=phone[0]
        
    #####################insert doginfo table##########################
    try:
        cursor = juso_db.cursor(pymysql.cursors.DictCursor)

        sql = "INSERT INTO `ieum`.`doginfo`(`id`,`breed`,`location`,`url`,`phone`,`datetime`,`sex`)"+\
        f" VALUES('{dognum}','{breed}','{location}','{detailurl}','{phone}','{date}','{sex}'); "

        cursor.execute(sql)
        result = cursor.fetchall()
        juso_db.commit()        
    except:
        print("doginfo")
        return 
    #######################파일 저장############################
    #server
    #dir="/home/upload/img"
    #local    
    dir="C://Users//sskim//Downloads"
    
    orginnamelist=[]
    for i in range(1,len(imgurls)):
        saveresult=saveimg(dir,imgurls[i])

        sql="INSERT INTO `ieum`.`file`(`path`,`system_name`,`size`,`type`,`origin_name`) "+\
        f"VALUES('{saveresult[0]}','{saveresult[1]}','0','{saveresult[3]}','{saveresult[4]}'); "

        cursor.execute(sql)
        result = cursor.fetchall()
        juso_db.commit()        
        orginnamelist.append(saveresult[4])
        
    #####################insert doginfoimages table##########################
    for orginname in orginnamelist:
        sql = f"SELECT id FROM `ieum`.`file` WHERE origin_name='{orginname}' ;"
        cursor.execute(sql)
        fileId = cursor.fetchall()
        print("fileId ",fileId[0]['id'])
        sql="INSERT INTO `ieum`.`doginfoimage`(`dogid`,`file_id`)" + \
        f" VALUES('{dognum}','{fileId[0]['id']}'); "
        cursor.execute(sql)
        fileId = cursor.fetchall()
    ####################insert doginfopredict table##########################
    
    predictlst=[]
    #predictlst = predict func()
    for i in predictlst

# %%
date=datetime.today()
month=int(datetime.today().month/10)*10+int(datetime.today().month%10)
day=int(datetime.today().day/10)*10+int(datetime.today().day%10)
endDate=str(datetime.today().year)+str(month)+ str(day)

# %%
if __name__ == "__main__":
    
    #크롤링 멈추는 날짜(등록일 기준)
    date=datetime.today()
    month=int(datetime.today().month/10)*10+int(datetime.today().month%10)
    day=int(datetime.today().day/10)*10+int(datetime.today().day%10)
    endDate=str(datetime.today().year)+"."+str(month) +"."+str(day)
    
    
    dogInfos=[]
    ##넘겨볼 페이지 갯수
    for pageNum in range(0,3):
        animalNums=getanimalnum(pageNum)
        cnt=0
        for num in animalNums:
            cnt+=1
            print("====개정보"+str(cnt+pageNum*20)+"===")
            info=getinfo(num)
            print("pageNum : ",pageNum,info)
            if(info[len(info)-4] in endDate):
                break
            dogInfos.append(info)
    print("####"*20)
    print("####"*20)
    print(f'Data Cnt: {len(dogInfos)}')
    print("####"*20)
    print("####"*20)
# Out:
# <Response [200]>
# ====개정보41===
# pageNum :  2 ['338342', 'https://www.zooseyo.or.kr/Yu_board/view.html?no=338342&page=1&animal=&area=', ['https://www.zooseyo.or.kr/dog_sale/photo_free/202103/1616999925_14111900.jpg', 'https://www.zooseyo.or.kr/dog_sale/photo_free/202103/1616999925_14111900.jpg', 'https://www.zooseyo.or.kr/dog_sale/photo_free/202103/1616999925_48737700.jpg', 'https://www.zooseyo.or.kr/dog_sale/photo_free/202103/1616999925_60831400.jpg', 'https://www.zooseyo.or.kr/dog_sale/photo_free/202103/1616999925_70254100.jpg'], '2021.03.29', '-', '진돗개', '시바', '오현석']
# ====개정보42===
# pageNum :  2 ['338335', 'https://www.zooseyo.or.kr/Yu_board/view.html?no=338335&page=1&animal=&area=', ['https://www.zooseyo.or.kr/dog_sale/photo_free/202103/1616992378_90733900.jpeg', 'https://www.zooseyo.or.kr/dog_sale/photo_free/202103/1616992378_90733900.jpeg', 'https://www.zooseyo.or.kr/dog_sale/photo_free/202103/1616992379_36308300.png', 'https://www.zooseyo.or.kr/dog_sale/photo_free/202103/1616992382_66417300.jpeg', 'https://www.zooseyo.or.kr/dog_sale/photo_free/202103/1616992382_76570100.jpeg'], '2021.03.29', '말티즈', '인천', '남아', '010-3139-4677']
# ====개정보43===
# pageNum :  2 ['338332', 'https://www.zooseyo.or.kr/Yu_board/view.html?no=338332&page=1&animal=&area=', ['https://www.zooseyo.or.kr/dog_sale/photo_free/202103/1
jpg', 'https://www.zooseyo.or.kr/dog_sale/photo_free/202103/1616988647_66965200.jpg', 'https://www.zooseyo.or.kr/dog_sale/photo_free/202103/1616988647_68790600.jpg', 'https://www.zooseyo.or.kr/dog_sale/photo_free/202103/1616988647_70211900.jpg'], '2021.03.29', '믹스견', '전국분양', '한쌍', '선택--']
# ====개정보55===
# pageNum :  2 ['338317', 'https://www.zooseyo.or.kr/Yu_board/view.html?no=338317&page=1&animal=&area=', ['https://www.zooseyo.or.kr/dog_sale/photo_free/202103/1616988576_16293100.jpg', 'https://www.zooseyo.or.kr/dog_sale/photo_free/202103/1616988576_16293100.jpg', 'https://www.zooseyo.or.kr/dog_sale/photo_free/202103/1616988576_27394800.jpg', 'https://www.zooseyo.or.kr/dog_sale/photo_free/202103/1616988576_29833500.jpg', 'https://www.zooseyo.or.kr/dog_sale/photo_free/202103/1616988576_32305300.jpg'], '2021.03.29', '믹스견', '전국분양', '여아', '선택--']
# ====개정보56===
# pageNum :  2 ['338316', 'https://www.zooseyo.or.kr/Yu_board/view.html?no=338316&page=1&animal=&area=', ['https://www.zooseyo.or.kr/dog_sale/photo_free/202103/1616988486_35835300.jpg', 'https://www.zooseyo.or.kr/dog_sale/photo_free/202103/1616988486_35835300.jpg', 'https://www.zooseyo.or.kr/dog_sale/photo_free/202103/1616988486_50602400.jpg', 'https://www.zooseyo.or.kr/dog_sale/photo_free/202103/1616988486_53031800.jpg', 'https://www.zooseyo.or.kr/dog_sale/photo_free/202103/1616988486_54322800.jpg'], '2021.03.29', '믹스견', '전국분양', '남아', '선택--']
# ====개정보57===
# pageNum :  2 ['338315', 'https://www.zooseyo.or.kr/Yu_board/view.html?no=338315&page=1&animal=&area=', ['https://www.zooseyo.or.kr/dog_sale/photo_free/202103/1616988374_52149500.jpg', 'https://www.zooseyo.or.kr/dog_sale/photo_free/202103/1616988374_52149500.jpg', 'https://www.zooseyo.or.kr/dog_sale/photo_free/202103/1616988374_68607600.jpg', 'https://www.zooseyo.or.kr/dog_sale/photo_free/202103/1616988374_71751900.jpg', 'https://www.zooseyo.or.kr/dog_sale/photo_free/202103/1616988374_74687500.jpg'], '2021.03.29', '믹스견', '전국분양', '한쌍', '연락처로']
# ====개정보58===
# pageNum :  2 ['338314', 'https://www.zooseyo.or.kr/Yu_board/view.html?no=338314&page=1&animal=&area=', ['https://www.zooseyo.or.kr/dog_sale/photo_free/202103/1616988278_25717800.jpg', 'https://www.zooseyo.or.kr/dog_sale/photo_free/202103/1616988278_25717800.jpg', 'https://www.zooseyo.or.kr/dog_sale/photo_free/202103/1616988278_46744700.jpg', 'https://www.zooseyo.or.kr/dog_sale/photo_free/202103/1616988278_50662800.jpg', 'https://www.zooseyo.or.kr/dog_sale/photo_free/202103/1616988278_53354400.jpg'], '2021.03.29', '믹스견', '전국분양', '여아', '선택--']
# ====개정보59===
# pageNum :  2 ['338313', 'https://www.zooseyo.or.kr/Yu_board/view.html?no=338313&page=1&animal=&area=', ['https://www.zooseyo.or.kr/dog_sale/photo_free/202103/1616988146_06368200.jpg', 'https://www.zooseyo.or.kr/dog_sale/photo_free/202103/1616988146_06368200.jpg', 'https://www.zooseyo.or.kr/dog_sale/photo_free/202103/1616988146_29079500.jpg', 'https://www.zooseyo.or.kr/dog_sale/photo_free/202103/1616988146_33188200.jpg', 'https://www.zooseyo.or.kr/dog_sale/photo_free/202103/1616988146_38097000.jpg'], '2021.03.29', '믹스견', '전국분양', '여아', '선택--']
# ====개정보60===
# pageNum :  2 ['338312', 'https://www.zooseyo.or.kr/Yu_board/view.html?no=338312&page=1&animal=&area=', ['https://www.zooseyo.or.kr/dog_sale/photo_free/202103/1616988069_51832500.jpg', 'https://www.zooseyo.or.kr/dog_sale/photo_free/202103/1616988069_51832500.jpg', 'https://www.zooseyo.or.kr/dog_sale/photo_free/202103/1616988069_71927800.jpg', 'https://www.zooseyo.or.kr/dog_sale/photo_free/202103/1616988069_76983500.jpg', 'https://www.zooseyo.or.kr/dog_sale/photo_free/202103/1616988069_81141500.jpg'], '2021.03.29', '믹스견', '전국분양', '여아', '선택--']
# ################################################################################
# ################################################################################
# Data Cnt: 20
# ################################################################################
# ################################################################################

# %%
##
for info in dogInfos:
    saveAndInsert(info)
# Out:
# doginfo
# doginfo
# doginfo
# doginfo
# doginfo
# doginfo
# doginfo
# directory :  C://Users//sskim//Downloads/2021331  파일명 : 961e1eb8-91ab-11eb-93ca-08d23e250ad9 원본 파일명 : 1616989297_12934700.jpg
# directory :  C://Users//sskim//Downloads/2021331  파일명 : 96581ac0-91ab-11eb-b2c9-08d23e250ad9 원본 파일명 : 1616989297_28034600.jpg
# directory :  C://Users//sskim//Downloads/2021331  파일명 : 96926192-91ab-11eb-a7ac-08d23e250ad9 원본 파일명 : 1616989297_30734000.jpg
# directory :  C://Users//sskim//Downloads/2021331  파일명 : 96d26f1c-91ab-11eb-b20f-08d23e250ad9 원본 파일명 : 1616989297_33216000.jpg
# fileId  226
# fileId  227
# fileId  228
# fileId  229
# error
# directory :  C://Users//sskim//Downloads/2021331  파일명 : 978b3abe-91ab-11eb-894c-08d23e250ad9 원본 파일명 : 1616989009_91225800.jpg
# directory :  C://Users//sskim//Downloads/2021331  파일명 : 97eaa130-91ab-11eb-93de-08d23e250ad9 원본 파일명 : 1616989009_94699000.jpg
# directory :  C://Users//sskim//Downloads/2021331  파일명 : 984afcd8-91ab-11eb-b8ae-08d23e250ad9 원본 파일명 : 1616989009_96647900.jpg
# fileId  230
# fileId  231
# directory :  C://Users//sskim//Downloads/2021331  파일명 : 9e6602ca-91ab-11eb-9869-08d23e250ad9 원본 파일명 : 1616988486_35835300.jpg
# directory :  C://Users//sskim//Downloads/2021331  파일명 : 9eaef702-91ab-11eb-9012-08d23e250ad9 원본 파일명 : 1616988486_50602400.jpg
# directory :  C://Users//sskim//Downloads/2021331  파일명 : 9ef9fb62-91ab-11eb-b710-08d23e250ad9 원본 파일명 : 1616988486_53031800.jpg
# error
# fileId  254
# fileId  255
# fileId  256
# fileId  257
# directory :  C://Users//sskim//Downloads/2021331  파일명 : 9f7cfe0c-91ab-11eb-a99d-08d23e250ad9 원본 파일명 : 1616988374_52149500.jpg
# directory :  C://Users//sskim//Downloads/2021331  파일명 : a0c96786-91ab-11eb-b6e7-08d23e250ad9 원본 파일명 : 1616988374_68607600.jpg
# directory :  C://Users//sskim//Downloads/2021331  파일명 : a12a2894-91ab-11eb-a1cd-08d23e250ad9 원본 파일명 : 1616988374_71751900.jpg
# directory :  C://Users//sskim//Downloads/2021331  파일명 : a1750da2-91ab-11eb-a145-08d23e250ad9 원본 파일명 : 1616988374_74687500.jpg
# fileId  258
# fileId  259
# fileId  260
# fileId  261
# directory :  C://Users//sskim//Downloads/2021331  파일명 : a1adeb92-91ab-11eb-a204-08d23e250ad9 원본 파일명 : 1616988278_25717800.jpg
# directory :  C://Users//sskim//Downloads/2021331  파일명 : a236eb82-91ab-11eb-948f-08d23e250ad9 원본 파일명 : 1616988278_46744700.jpg
# directory :  C://Users//sskim//Downloads/2021331  파일명 : a2c6de00-91ab-11eb-a322-08d23e250ad9 원본 파일명 : 1616988278_50662800.jpg
# error
# fileId  262
# fileId  263
# fileId  264
# fileId  265
# directory :  C://Users//sskim//Downloads/2021331  파일명 : a37bbe9e-91ab-11eb-bda2-08d23e250ad9 원본 파일명 : 1616988146_06368200.jpg
# directory :  C://Users//sskim//Downloads/2021331  파일명 : a4416d8a-91ab-11eb-ba04-08d23e250ad9 원본 파일명 : 1616988146_29079500.jpg
# directory :  C://Users//sskim//Downloads/2021331  파일명 : a503d852-91ab-11eb-98b2-08d23e250ad9 원본 파일명 : 1616988146_33188200.jpg
# directory :  C://Users//sskim//Downloads/2021331  파일명 : a5d6070c-91ab-11eb-81ba-08d23e250ad9 원본 파일명 : 1616988146_38097000.jpg
# fileId  266
# fileId  267
# fileId  268
# fileId  269
# directory :  C://Users//sskim//Downloads/2021331  파일명 : a67beb80-91ab-11eb-8435-08d23e250ad9 원본 파일명 : 1616988069_51832500.jpg
# directory :  C://Users//sskim//Downloads/2021331  파일명 : a793bfc0-91ab-11eb-8973-08d23e250ad9 원본 파일명 : 1616988069_71927800.jpg
# directory :  C://Users//sskim//Downloads/2021331  파일명 : a8717e78-91ab-11eb-8e92-08d23e250ad9 원본 파일명 : 1616988069_76983500.jpg
# directory :  C://Users//sskim//Downloads/2021331  파일명 : a8fd1410-91ab-11eb-8957-08d23e250ad9 원본 파일명 : 1616988069_81141500.jpg
# fileId  270
# fileId  271
# fileId  272
# fileId  273

# %%
"""
for info in dogInfos:
    if(info[2] == []) :
        continue
    for img in info[2][1:]:
        continue
        ##요기에 원하는 경로
##        saveimg("C:/Users/sskim/Downloads/Dogs",img,info[len(info)-3],info[0])
"""
