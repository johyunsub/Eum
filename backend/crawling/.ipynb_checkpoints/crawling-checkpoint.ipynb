# %%
pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\sskim\anaconda3\lib\site-packages (4.8.2)
# Requirement already satisfied: soupsieve>=1.2 in c:\users\sskim\anaconda3\lib\site-packages (from beautifulsoup4) (1.9.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup as bs
import urllib.request
from urllib.parse import quote_plus
import requests
import os

# %%
def getanimalnum(pageNum):
    baseUrl = 'https://www.zooseyo.or.kr/Yu_board/freesale_ty_1.html?animal=%EA%B0%95%EC%95%84%EC%A7%80&area=&ty=1&page='   
    url = baseUrl+str(pageNum)  
    req=requests.get(url)
    print(req)
    html = req.text
    soup = bs(html, "html.parser")
    info=soup.select('a[href]')
    checkpoint=False
    ct=0;
    animalnum=[]
    for i in info:
        tags=i.get('href')
        if("sell_up.html?gort=g"==tags):
            ct+=1
        num=tags.split("&")[0].split("?")
        if(ct>1 and num[0]=="view.html"):
            animalnum.append(num[1].split("=")[1])
    print("*"*10)
    return animalnum

# %%
def getinfo(animalNum):
    preUrl='https://www.zooseyo.or.kr/Yu_board/view.html?no='
    postUrl='&page=1&animal=&area='
    url=preUrl+animalNum+postUrl
    dogsinfo=[]
    
    req=requests.get(url)
    print(url)
    print(req)
    html = req.text
    soup = bs(html, "html.parser")
    
    #url 등록
    dogsinfo.append(url)
    
    #등록일 추가
    
    ##
    
    
    ##img 추가
    imginfo=soup.select('img[src]')
    imglist=[]
    for i in imginfo:
        tags=i.get('src')
        if('/dog_sale/' in tags):
            print(tags)
            imglist.append('https://www.zooseyo.or.kr'+tags)
    dogsinfo.append(imglist)
    return imglist

# %%
def saveimg(directory,url,img_name):
    n=1
    save_path='downloads'
    save_root = 'downloads'
    if not os.path.exists(save_root):os.makedirs(save_root)
    with urlopen(url) as f:
        with open(os.path.join(save_path, str(n)+'.jpg'),'wb') as h: # w - write b - binary
            img = f.read()
            h.write(img)
    print(f"폴더명 {directory}")
    print(f"url {url}")
    print(f"파일명 {img}")

# %%
for i in getinfo(getanimalnum(1)[3]):
    print(i)
    saveimg("",i,str(123))
# Out:
# <Response [200]>
# **********
# https://www.zooseyo.or.kr/Yu_board/view.html?no=337105&page=1&animal=&area=
# <Response [200]>
# /dog_sale/photo_free/202103/1615469599_77843900.jpg
# /dog_sale/photo_free/202103/1615469599_77843900.jpg
# /dog_sale/photo_free/202103/1615469600_01322500.jpg
# /dog_sale/photo_free/202103/1615469600_06078400.jpg
# /dog_sale/photo_free/202103/1615469600_08939600.jpg
# https://www.zooseyo.or.kr/dog_sale/photo_free/202103/1615469599_77843900.jpg
# 폴더명
# url https://www.zooseyo.or.kr/dog_sale/photo_free/202103/1615469599_77843900.jpg
# 파일명 b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x02\x01\x01\x01\x01\x01\x02\x01\x01\x01\x02\x02\x02\x02\x02\x04\x03\x02\x02\x02\x02\x05\x04\x04\x03\x04\x06\x05\x06\x06\x06\x05\x06\x06\x06\x07\t\x08\x06\x07\t\x07\x06\x06\x08\x0b\x08\t\n\n\n\n\n\x06\x08\x0b\x0c\x0b\n\x0c\t\n\n\n\xff\xdb\x00C\x01\x02\x02\x02\x02\x02\x02\x05\x03\x03\x05\n\x07\x06\x07\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\xff\xc0\x00\x11\x08\x07\xe0\x05\xe8\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1e\x00\x00\x01\x04\x03\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x04\x02\x03\x05\x06\x00\x01\x07\x08\t\n\xff\xc4\x00M\x10\x00\x01\x03\x03\x03\x02\x04\x03\x06\x05\x04\x01\x03\x01\x00\x13\x01\x02\x03\x11\x00\x04!\x05\x121\x06A\x13"Qa\x07q\x81\x142\x91\xa1\xb1\xf0\x08#B\xc1\xd1\x15R\xe1\xf13\t\x16$brC\x82\x92\x17%4S\xa2\x18\x83\xb2\n&5Dc\xa3\xc2\xff\xc4\x00\x1d\x01\x00\x03\x01\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t